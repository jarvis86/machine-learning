# %% [markdown]
# <a href="https://www.kaggle.com/code/jarvis78/instagram?scriptVersionId=117855956" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/list-of-mostfollowed-instagram-accounts/List of most-followed Instagram accounts.csv

# %%
df=pd.read_csv("/kaggle/input/list-of-mostfollowed-instagram-accounts/List of most-followed Instagram accounts.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Rank      Username              Owner Followers(millions)[2]  \
# 0           0    1    @instagram          Instagram                    586
# 1           1    2    @cristiano  Cristiano Ronaldo                    531
# 2           2    3     @leomessi       Lionel Messi                    417
# 3           3    4  @kyliejenner       Kylie Jenner                    377
# 4           4    5  @selenagomez       Selena Gomez                    367
#
#                                Profession/Activity Country/Continent
# 0                            Social media platform     United States
# 1                                       Footballer          Portugal
# 2                                       Footballer         Argentina
# 3  Television personality, model and businesswoman     United States
# 4             Musician, actress, and businesswoman     United States

# %%
df.drop(df.columns[0],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Rank      Username              Owner Followers(millions)[2]  \
# 0    1    @instagram          Instagram                    586
# 1    2    @cristiano  Cristiano Ronaldo                    531
# 2    3     @leomessi       Lionel Messi                    417
# 3    4  @kyliejenner       Kylie Jenner                    377
# 4    5  @selenagomez       Selena Gomez                    367
#
#                                Profession/Activity Country/Continent
# 0                            Social media platform     United States
# 1                                       Footballer          Portugal
# 2                                       Footballer         Argentina
# 3  Television personality, model and businesswoman     United States
# 4             Musician, actress, and businesswoman     United States

# %%
df.drop(index=50,inplace=True)
df.drop(index=0,inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 1 to 49
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    49 non-null     object
#  1   Username                49 non-null     object
#  2   Owner                   49 non-null     object
#  3   Followers(millions)[2]  49 non-null     object
#  4   Profession/Activity     49 non-null     object
#  5   Country/Continent       49 non-null     object
# dtypes: object(6)
# memory usage: 2.7+ KB

# %%
df["Followers(millions)[2]"]=df["Followers(millions)[2]"].astype("str").astype("float")

# %%
plt.figure(figsize=(20,15))
sns.barplot(df["Owner"].head(10),df["Followers(millions)[2]"].head(10))
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Owner', ylabel='Followers(millions)[2]'>

# %%
plt.figure(figsize=(20,15))
plt.scatter(df["Followers(millions)[2]"].head(),df["Owner"].head())
